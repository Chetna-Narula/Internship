# %%
# !pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\users\asus\anaconda3\lib\site-packages (4.8.0)
# Requirement already satisfied: trio~=0.17 in c:\users\asus\anaconda3\lib\site-packages (from selenium) (0.22.0)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\asus\anaconda3\lib\site-packages (from selenium) (2021.10.8)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\asus\anaconda3\lib\site-packages (from selenium) (0.9.2)
# Requirement already satisfied: urllib3[socks]~=1.26 in c:\users\asus\anaconda3\lib\site-packages (from selenium) (1.26.9)
# Requirement already satisfied: sortedcontainers in c:\users\asus\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\asus\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.15.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in c:\users\asus\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.1.0)
# Requirement already satisfied: idna in c:\users\asus\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.3)
# Requirement already satisfied: sniffio in c:\users\asus\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: async-generator>=1.9 in c:\users\asus\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: outcome in c:\users\asus\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\asus\anaconda3\lib\site-packages (from trio~=0.17->selenium) (21.4.0)
# Requirement already satisfied: pycparser in c:\users\asus\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: wsproto>=0.14 in c:\users\asus\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\asus\anaconda3\lib\site-packages (from urllib3[socks]~=1.26->selenium) (1.7.1)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\asus\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)

# %%
# import debugger
import re

# selenium
import selenium
import pandas as pd
from selenium import webdriver

# Beautiful soup
from bs4 import BeautifulSoup
import requests

# add time
import time

from selenium.common.exceptions import NoSuchElementException, StaleElementReferenceException

from selenium.webdriver.support.ui import WebDriverWait

# %%
import warnings
import requests
import re
warnings.filterwarnings('ignore')

from selenium.webdriver.common.by import By
import time

# %% [markdown]
# ### Answer No.01

# %%
# first, connect to the webdriver
driver=webdriver.Chrome(r"C:\Users\ASUS\Downloads\chromedriver_win32 (3)\chromedriver.exe")
# getting the webpage of mentioned url
url = 'https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos'
driver.get(url)

# %%
# creating empty list for scraping the data

Rank = []
Name = []
Artist = []
Date = []
Views = []

# %%
# scraping Rank of the videos
try:
    for i in driver.find_elements(By.XPATH,"//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[1]"):
        Rank.append(i.text)
except NoSuchElementException:
    Rank.append("-")
        
# Scraping Name of the videos
try:
    for i in driver.find_elements(By.XPATH,"//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[2]"):
        Name.append(i.text)
except NoSuchElementException:
    Name.append("-")
        
# Scraping Artist of the videos
try:
    for i in driver.find_elements(By.XPATH,"//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[3]"):
        Artist.append(i.text)
except NoSuchElementException:
    Artist.append("-")
        
# Scraping Upload_Date of the videos
try:
    for i in driver.find_elements(By.XPATH,"//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[5]"):
        Date.append(i.text)
except NoSuchElementException:
    Date.append("-")
        
# Scraping Views of the videos
try:
    for i in driver.find_elements(By.XPATH,"//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[4]"):
        Views.append(i.text)
except NoSuchElementException:
    Views.append("-")
        
# creating DataFrame for scraped data
Wiki = pd.DataFrame({})
Wiki['Rank'] = Rank
Wiki['Name'] = Name
Wiki['Artist'] = Artist
Wiki['Upload Date'] = Date
Wiki['Views (in Billions)'] = Views

# removing stray numbers from Name column
Wiki.Name = Wiki.Name.apply(lambda x:x[:-4].strip('"'))
Wiki
# Out:
#    Rank                                       Name  \
# 0    1.                           Baby Shark Dance
# 1    2.                                  Despacito
# 2    3.                       Johny Johny Yes Papa
# 3    4.                                  Bath Song
# 4    5.                               Shape of You
# 5    6.                              See You Again
# 6    7.                Phonics Song with Two Words
# 7    8.                          Wheels on the Bus
# 8    9.                                Uptown Funk
# 9   10.  Learning Colors – Colorful Eggs on a Farm
# 10  11.                              Gangnam Style
# 11  12.   Masha and the Bear – Recipe for Disaster
# 12  13.                             Dame Tu Cosita
# 13  14.                                      Sugar
# 14  15.                                     Axel F
# 15  16.                                       Roar
# 16  17.                             Counting Stars
# 17  18.                                      Sorry
# 18  19.                          Thinking Out Loud
# 19  20.                        Baa Baa Black Sheep
# 20  21.           Waka Waka (This Time for Africa)
# 21  22.                                 Dark Horse
# 22  23.                                      Faded
# 23  24.                                 Let Her Go
# 24  25.                             Girls Like You
# 25  26.                                    Perfect
# 26  27.                                   Bailando
# 27  28.                                    Lean On
# 28  29.                             Lakdi Ki Kathi
# 29  30.          Humpty the train on a fruits ride
#
#                                            Artist        Upload Date  \
# 0     Pinkfong Baby Shark - Kids' Songs & Stories      June 17, 2016
# 1                                      Luis Fonsi   January 12, 2017
# 2                                     LooLoo Kids    October 8, 2016
# 3                      Cocomelon – Nursery Rhymes        May 2, 2018
# 4                                      Ed Sheeran   January 30, 2017
# 5                                     Wiz Khalifa      April 6, 2015
# 6                                       ChuChu TV      March 6, 2014
# 7                      Cocomelon – Nursery Rhymes       May 24, 2018
# 8                                     Mark Ronson  November 19, 2014
# 9                                     Miroshka TV  February 27, 2018
# 10                                            Psy      July 15, 2012
# 11                                     Get Movies   January 31, 2012
# 12                                      El Chombo      April 5, 2018
# 13                                       Maroon 5   January 14, 2015
# 14                                     Crazy Frog      June 16, 2009
# 15                                     Katy Perry  September 5, 2013
# 16                                    OneRepublic       May 31, 2013
# 17                                  Justin Bieber   October 22, 2015
# 18                                     Ed Sheeran    October 7, 2014
# 19                     Cocomelon – Nursery Rhymes      June 25, 2018
# 20                                        Shakira       June 4, 2010
# 21                                     Katy Perry  February 20, 2014
# 22                                    Alan Walker   December 3, 2015
# 23                                      Passenger      July 25, 2012
# 24                                       Maroon 5       May 31, 2018
# 25                                     Ed Sheeran   November 9, 2017
# 26                               Enrique Iglesias     April 11, 2014
# 27                                    Major Lazer     March 22, 2015
# 28                                   Jingle Toons      June 14, 2018
# 29  Kiddiestv Hindi – Nursery Rhymes & Kids Songs   January 26, 2018
#
#    Views (in Billions)
# 0                12.37
# 1                 8.09
# 2                 6.63
# 3                 6.03
# 4                 5.92
# 5                 5.79
# 6                 5.17
# 7                 4.95
# 8                 4.84
# 9                 4.83
# 10                4.70
# 11                4.53
# 12                4.24
# 13                3.82
# 14                3.76
# 15                3.73
# 16                3.73
# 17                3.63
# 18                3.55
# 19                3.51
# 20                3.48
# 21                3.45
# 22                3.41
# 23                3.38
# 24                3.37
# 25                3.37
# 26                3.34
# 27                3.33
# 28                3.32
# 29                3.31

# %%
print(len(Rank),
len(Name),
len(Artist),
len(Date),
len(Views))
# Out:
# 30 30 30 30 30

# %%
driver.close()

# %% [markdown]
# ### Answer No.02

# %%
# connecting to the webdriver
driver=webdriver.Chrome(r"C:\Users\ASUS\Downloads\chromedriver_win32 (3)\chromedriver.exe")
# getting the webpage of mentioned url
url=('https://www.bcci.tv/')
driver.get(url)

# %%
btn=driver.find_element(By.XPATH,"//a[@class='nav-link ']")
driver.get(btn.get_attribute("href"))
time.sleep(3)

# %%
# creating empty lists for scraping the data
Match_Title = []
Series = []
Place = []
Date = []
Time = []

# %%
for i in driver.find_elements(By.XPATH,"//span[@class='matchOrderText ng-binding ng-scope']"):
    Match_Title.append(i.text)

# %%
Match_Title.remove('4th Test -')
Match_Title
# Out:
# ['1st ODI -', '2nd ODI -', '3rd ODI -']

# %%
Series=[]
for i in driver.find_elements(By.XPATH,"//div[@class='fixture-card-mid d-flex align-items-center justify-content-between']"):
    Series.append(i.text.replace('\n',''))

# %%
Series
# Out:
# ['IndiavsAustralia', 'IndiavsAustralia', 'IndiavsAustralia']

# %%
Place=[]
for i in driver.find_elements(By.XPATH,"//span[@class='ng-binding ng-scope']"):
    Place.append(i.text)

# %%
Place.remove('Narendra Modi Stadium,')
Place
# Out:
# ['Wankhede Stadium,',
#  'Dr YS Rajasekhara Reddy ACA-VDCA Cricket Stadium,',
#  'MA Chidambaram Stadium,']

# %%
for i in driver.find_elements(By.XPATH,"//div[@class='match-top-info d-flex align-items-center justify-content-between']"):
    Date.append(i.text.replace('\n',' '))

# %%
Date.remove('9 MAR 2023 LIVE')
Date
# Out:
# ['17 MAR 2023 1:30 PM IST',
#  '19 MAR 2023 1:30 PM IST',
#  '22 MAR 2023 1:30 PM IST']

# %%
date=[i.split(' ',3)[:3] for i in Date]
date=[' '.join(i) for i in date]
Time=[i.split(' ',3)[-1] for i in Date]

# %%
Time
# Out:
# ['1:30 PM IST', '1:30 PM IST', '1:30 PM IST']

# %%
# creating data frame
fixture=pd.DataFrame({'Match Title': Match_Title,
                          "Series": Series,
                          "Place": Place,
                          "Date": date,
                          "Time": Time})
fixture
# Out:
#   Match Title            Series  \
# 0   1st ODI -  IndiavsAustralia
# 1   2nd ODI -  IndiavsAustralia
# 2   3rd ODI -  IndiavsAustralia
#
#                                                Place         Date         Time
# 0                                  Wankhede Stadium,  17 MAR 2023  1:30 PM IST
# 1  Dr YS Rajasekhara Reddy ACA-VDCA Cricket Stadium,  19 MAR 2023  1:30 PM IST
# 2                            MA Chidambaram Stadium,  22 MAR 2023  1:30 PM IST

# %%
driver.close()

# %% [markdown]
# ### Answer No.03

# %%
# connecting to the web driver
driver=webdriver.Chrome(r"C:\Users\ASUS\Downloads\chromedriver_win32 (3)\chromedriver.exe")

# getting the webpage of mentioned url
url = ("https://statisticstimes.com/")
driver.get(url)

# %%
# clicking on Economy button
driver.find_element(By.XPATH,"//div[@class='navbar']/div[2]/button").click()

# clicking on India
driver.find_element(By.XPATH,"//div[@class='dropdown-content']/a[3]").click()
time.sleep(3)

# clicking on GDP of Indian Economy
GDP = driver.find_element(By.XPATH,"/html/body/div[2]/div[2]/div[2]/ul/li[1]/a").click()
time.sleep(3)

# %%
# creating empty list
Rank = []
State = []
GSDP1 = []
GSDP2 = []
Share = []
GDP_billion = []

# scraping Rank
try:
    for i in driver.find_elements_by_xpath("//table[@class='display dataTable']/tbody/tr/td[1]"):
        Rank.append(i.text)
except NoSuchElementException:
    Rank.append("_")
    
# scraping State
try:
    for i in driver.find_elements_by_xpath("//table[@class='display dataTable']/tbody/tr/td[2]"):
        State.append(i.text)
except NoSuchElementException:
    State.append("_")
    
# scraping GSDP at current price (19-20)
try:
    for i in driver.find_elements_by_xpath("//table[@class='display dataTable']/tbody/tr/td[3]"):
        GSDP1.append(i.text)
except NoSuchElementException:
    GSDP1.append("_")
    
# scraping GSDP at current price (18-19)
try:
    for i in driver.find_elements_by_xpath("//table[@class='display dataTable']/tbody/tr/td[4]"):
        GSDP2.append(i.text)
except NoSuchElementException:
    GSDP2.append("_")
    
# scraping Share (18-19)
try:
    for i in driver.find_elements_by_xpath("//table[@class='display dataTable']/tbody/tr/td[5]"):
        Share.append(i.text)
except NoSuchElementException:
    Share.append("_")
    
# scraping GDP $ billion
try:
    for i in driver.find_elements_by_xpath("//table[@class='display dataTable']/tbody/tr/td[6]"):
        GDP_billion.append(i.text)
except NoSuchElementException:
    GDP_billion.append("_")
    
    
# creating DataFrame from the scraped data
GDP = pd.DataFrame({})
GDP['Rank'] = Rank
GDP['State'] = State
GDP['GSDP at current price (19-20)'] = GSDP1
GDP['GSDP at current price (18-19)'] = GSDP2
GDP['Share (18-19)'] = Share
GDP['GDP($ billion)'] = GDP_billion
GDP
# Out:
#    Rank                      State GSDP at current price (19-20)  \
# 0     1                Maharashtra                             -
# 1     2                 Tamil Nadu                     1,845,853
# 2     3              Uttar Pradesh                     1,687,818
# 3     4                    Gujarat                             -
# 4     5                  Karnataka                     1,631,977
# ..  ...                        ...                           ...
# 61   29                     Sikkim                        28,391
# 62   30                   Nagaland                             -
# 63   31          Arunachal Pradesh                             -
# 64   32                    Mizoram                        24,424
# 65   33  Andaman & Nicobar Islands                             -
#
#    GSDP at current price (18-19) Share (18-19) GDP($ billion)
# 0                      2,632,792        13.94%        399.921
# 1                      1,630,208         8.63%        247.629
# 2                      1,584,764         8.39%        240.726
# 3                      1,502,899         7.96%        228.290
# 4                      1,493,127         7.91%        226.806
# ..                           ...           ...            ...
# 61                        25,141         0.15%         17,060
# 62                        24,534         0.15%              -
# 63                        22,488         0.13%              -
# 64                        20,947         0.13%         17,797
# 65                             -             -              -
#
# [66 rows x 6 columns]

# %%
driver.close()

# %% [markdown]
# ### Answer No.04

# %%
# first, connect to the webdriver
driver=webdriver.Chrome(r"C:\Users\ASUS\Downloads\chromedriver_win32 (3)\chromedriver.exe")
# getting the webpage of mentioned url
url = ("https://github.com/")
driver.get(url)

# %%
# getting explore button and clicking on it
explore = driver.find_element(By.XPATH,"/html/body/div[1]/div[1]/header/div/div[2]/div/nav/ul/li[3]/button").click()

# selecting trending option
trend_url = driver.find_element(By.XPATH,"/html/body/div[1]/div[1]/header/div/div[2]/div/nav/ul/li[3]/div/ul[3]/li[3]/a")
urls = trend_url.get_attribute("href")
driver.get(urls)

# %%
# creating empty list
URLs = []
repository_title = []
Description = []
Contributors = []
Language = []
lang = []

# fetching urls for each repository
repository = driver.find_elements(By.XPATH,"//h1[@class='h3 lh-condensed']//a")
for i in repository:
    URLs.append(i.get_attribute("href"))
    
# scraping Repository title data
title = driver.find_elements(By.XPATH,"//h1[@class = 'h3 lh-condensed']")
for i in title:
    repository_title.append(i.text)
    
# scraping data from all repository page
for i in URLs:
    driver.get(i)
    time.sleep(5)
    
    # scraping Repository Description data 
    try:
        desc = driver.find_element(By.XPATH,"//p[@class='f4 mt-3']")
        Description.append(desc.text)
    except NoSuchElementException:
        Description.append('-')
        
        
    # scraping Contributors Count data
    try:
        contributor = driver.find_element(By.XPATH,"//*[contains(text(),'    Contributors ')]")
        Contributors.append(contributor.text.replace('Contributors',''))
    except NoSuchElementException:
        Contributors.append('-')
    
    
    # scraping Languages used data
    try:
        for i in driver.find_elements(By.XPATH,"//ul[@class= 'list-style-none']//li//span[1]"):
            lang.append(i.text)
        Language.append(lang)
    except NoSuchElementException:
        Language.append('-')
        
        
# Data Framing
Github = pd.DataFrame({})
Github['Repository Title'] = repository_title
Github['Repository Description'] = Description
Github['Contributors Count'] = Contributors
Github['Language Used'] = Language
Github
# Out:
#                              Repository Title Repository Description  \
# 0              togethercomputer / OpenChatKit                      -
# 1                  microsoft / visual-chatgpt                      -
# 2                       ggerganov / llama.cpp                      -
# 3                   GanymedeNil / document.ai                      -
# 4                    kaixindelele / ChatPaper                      -
# 5                     ggerganov / whisper.cpp                      -
# 6                      sindresorhus / awesome                      -
# 7    camenduru / stable-diffusion-webui-colab                      -
# 8          donnemartin / system-design-primer                      -
# 9   davinci1012 / pinduoduo_backdoor_unpacker                      -
# 10          oobabooga / text-generation-webui                      -
# 11                   termux / termux-packages                      -
# 12                    tangly1024 / NotionNext                      -
# 13                sherlock-project / sherlock                      -
# 14                            neovim / neovim                      -
# 15                        bmaltais / kohya_ss                      -
# 16                  mckaywrigley / chatbot-ui                      -
# 17                The-Art-of-Hacking / h4cker                      -
# 18               CS-BAOYAN / CSSummerCamp2023                      -
# 19                        Genymobile / scrcpy                      -
# 20                 hiifeng / V2ray-for-Doprax                      -
# 21                         futantan / OpenGpt                      -
# 22                       zauberzeug / nicegui                      -
# 23                            iptv-org / iptv                      -
# 24        yuvalsuede / ai-component-generator                      -
#
#    Contributors Count                                      Language Used
# 0                   7  [Python, Shell, Python, C, C++, Python, Makefi...
# 1                   9  [Python, Shell, Python, C, C++, Python, Makefi...
# 2                  16  [Python, Shell, Python, C, C++, Python, Makefi...
# 3                   2  [Python, Shell, Python, C, C++, Python, Makefi...
# 4                   4  [Python, Shell, Python, C, C++, Python, Makefi...
# 5                  65  [Python, Shell, Python, C, C++, Python, Makefi...
# 6                 552  [Python, Shell, Python, C, C++, Python, Makefi...
# 7                  10  [Python, Shell, Python, C, C++, Python, Makefi...
# 8                 117  [Python, Shell, Python, C, C++, Python, Makefi...
# 9                   2  [Python, Shell, Python, C, C++, Python, Makefi...
# 10                 23  [Python, Shell, Python, C, C++, Python, Makefi...
# 11                382  [Python, Shell, Python, C, C++, Python, Makefi...
# 12                 21  [Python, Shell, Python, C, C++, Python, Makefi...
# 13                195  [Python, Shell, Python, C, C++, Python, Makefi...
# 14                948  [Python, Shell, Python, C, C++, Python, Makefi...
# 15                  7  [Python, Shell, Python, C, C++, Python, Makefi...
# 16                  -  [Python, Shell, Python, C, C++, Python, Makefi...
# 17                 14  [Python, Shell, Python, C, C++, Python, Makefi...
# 18                  2  [Python, Shell, Python, C, C++, Python, Makefi...
# 19                108  [Python, Shell, Python, C, C++, Python, Makefi...
# 20                  4  [Python, Shell, Python, C, C++, Python, Makefi...
# 21                  5  [Python, Shell, Python, C, C++, Python, Makefi...
# 22                 14  [Python, Shell, Python, C, C++, Python, Makefi...
# 23                216  [Python, Shell, Python, C, C++, Python, Makefi...
# 24                  3  [Python, Shell, Python, C, C++, Python, Makefi...

# %%
driver.close()

# %% [markdown]
# ### Answer No.05

# %%
# connecting to the web driver
driver=webdriver.Chrome(r"C:\Users\ASUS\Downloads\chromedriver_win32 (3)\chromedriver.exe")
# getting the webpage of mentioned url
url = ("https://www.billboard.com/")
driver.get(url)

# %%
# clicking on option button
charts=driver.find_element(By.XPATH,"/html/body/div[3]/header/div/div[2]/div/div/div[2]/div[2]/div/div/nav/ul/li[1]/a").click()

# %%
# clicking on option button
full_chart=driver.find_element(By.XPATH,"/html/body/div[3]/main/div[2]/div[1]/div[1]/div/div/div[3]/a").click()

# %%
# creating empty lists
Song_Name = []
Artist_Name =[]
Last_week_rank = []
Peak_rank = []
Weeks_on_board = []

# getting urls for top 100 songs
urls = driver.find_element_by_xpath("//li[@class='header__submenu__list__element']//a")
page_url = urls.get_attribute("href")
driver.get(page_url)
time.sleep(4)

# scraping data of song names
for i in driver.find_elements_by_xpath("//span[@class='chart-element__information__song text--truncate color--primary']"):
    Song_Name.append(i.text)
    
# scraping data of artist names
for i in driver.find_elements_by_xpath("//span[@class='chart-element__information__artist text--truncate color--secondary']"):
    Artist_Name.append(i.text)
    
# scraping data of last week ranks
for i in driver.find_elements_by_xpath("//div[@class='chart-element__meta text--center color--secondary text--last']"):
    Last_week_rank.append(i.text)
    

# scraping data of peak ranks
for i in driver.find_elements_by_xpath("//div[@class='chart-element__meta text--center color--secondary text--peak']"):
    Peak_rank.append(i.text)       
    
    
# scraping data of weeks on board
for i in driver.find_elements_by_xpath("//div[@class='chart-element__meta text--center color--secondary text--week']"):
    Weeks_on_board.append(i.text)
    
    
# creating dataframe for scraped data
billiboard = pd.DataFrame({})
billiboard['Name'] = Song_Name
billiboard['Artist'] = Artist_Name
billiboard['Last Week Rank'] = Last_week_rank
billiboard['Peak Rank'] = Peak_rank
billiboard['Weeks on board'] = Weeks_on_board
billiboard

# %% [markdown]
# ### Answer No.06

# %%
# connecting to the web driver
driver1=webdriver.Chrome(r"C:\Users\ASUS\Downloads\chromedriver_win32 (3)\chromedriver.exe")

# getting the webpage of mentioned url
url = ("https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare/")
driver1.get(url)
time.sleep(3)

# %%
# creating empty lists
Book_name = []
Author_name = []
Volumes_sold = []
Publisher = []
Genre = []


# scraping book names data
for i in driver1.find_elements(By.XPATH,"//tbody//tr//td[2]"):
    Book_name.append(i.text)

    
# scraping author names data
for i in driver1.find_elements(By.XPATH,"//tbody//tr//td[3]"):
    try:
        if i.text == '0' : raise NoSuchElementException
        Author_name.append(i.text)
    except NoSuchElementException:
        Author_name.append('-')
time.sleep(3)


# scraping data of volumes sold
for i in driver1.find_elements(By.XPATH,"//tbody//tr//td[4]"):
    Volumes_sold.append(i.text)
    
    
# scraping data of publisher names
for i in driver1.find_elements(By.XPATH,"//tbody//tr//td[5]"):
    Publisher.append(i.text)
    
    
# scraping  data of genre
for i in driver1.find_elements(By.XPATH,"//tbody//tr//td[6]"):
    Genre.append(i.text)    
    
    
# creating dataframe for scraped data
Novels = pd.DataFrame({})
Novels['Book Name'] = Book_name
Novels['Author'] = Author_name
Novels['Volume sold'] = Volumes_sold
Novels['Publisher'] = Publisher
Novels['Genre'] = Genre
Novels
# Out:
#                                             Book Name            Author  \
# 0                                   Da Vinci Code,The        Brown, Dan
# 1                Harry Potter and the Deathly Hallows     Rowling, J.K.
# 2            Harry Potter and the Philosopher's Stone     Rowling, J.K.
# 3           Harry Potter and the Order of the Phoenix     Rowling, J.K.
# 4                                Fifty Shades of Grey      James, E. L.
# ..                                                ...               ...
# 95                                          Ghost,The    Harris, Robert
# 96                     Happy Days with the Naked Chef     Oliver, Jamie
# 97              Hunger Games,The:Hunger Games Trilogy  Collins, Suzanne
# 98  Lost Boy,The:A Foster Child's Search for the L...      Pelzer, Dave
# 99  Jamie's Ministry of Food:Anyone Can Learn to C...     Oliver, Jamie
#
#    Volume sold        Publisher                        Genre
# 0    5,094,805       Transworld  Crime, Thriller & Adventure
# 1    4,475,152       Bloomsbury           Children's Fiction
# 2    4,200,654       Bloomsbury           Children's Fiction
# 3    4,179,479       Bloomsbury           Children's Fiction
# 4    3,758,936     Random House              Romance & Sagas
# ..         ...              ...                          ...
# 95     807,311     Random House   General & Literary Fiction
# 96     794,201          Penguin        Food & Drink: General
# 97     792,187  Scholastic Ltd.          Young Adult Fiction
# 98     791,507            Orion           Biography: General
# 99     791,095          Penguin        Food & Drink: General
#
# [100 rows x 5 columns]

# %%
driver1.close()

# %% [markdown]
# ### Answer No.07

# %%
# !pip install webdriver-manager
# Out:
# Requirement already satisfied: webdriver-manager in c:\users\asus\anaconda3\lib\site-packages (3.8.5)
# Requirement already satisfied: requests in c:\users\asus\anaconda3\lib\site-packages (from webdriver-manager) (2.27.1)
# Requirement already satisfied: python-dotenv in c:\users\asus\anaconda3\lib\site-packages (from webdriver-manager) (1.0.0)
# Requirement already satisfied: packaging in c:\users\asus\anaconda3\lib\site-packages (from webdriver-manager) (21.3)
# Requirement already satisfied: tqdm in c:\users\asus\anaconda3\lib\site-packages (from webdriver-manager) (4.64.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\asus\anaconda3\lib\site-packages (from packaging->webdriver-manager) (3.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\asus\anaconda3\lib\site-packages (from requests->webdriver-manager) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\asus\anaconda3\lib\site-packages (from requests->webdriver-manager) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\asus\anaconda3\lib\site-packages (from requests->webdriver-manager) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\asus\anaconda3\lib\site-packages (from requests->webdriver-manager) (3.3)
# Requirement already satisfied: colorama in c:\users\asus\anaconda3\lib\site-packages (from tqdm->webdriver-manager) (0.4.4)

# %%
from webdriver_manager.chrome import ChromeDriverManager

# %%
driver=webdriver.Chrome(ChromeDriverManager().install())
# Out:
# [WDM] - Downloading: 100%|██████████| 6.79M/6.79M [00:01<00:00, 4.53MB/s]

# %%
# getting the webpage of mentioned url
url = ("http://www.imdb.com/list/ls095964455/")
driver.get(url)

# %%
# creating empty lists
Name = []
Year_span = []
Genre = []
Run_time = []
Ratings = []
Votes = []

# scraped data of Names
for i in driver.find_elements(By.XPATH,"//h3[@class='lister-item-header']/a"):
    Name.append(i.text)
    
    
# scraped data of Year span
for i in driver.find_elements(By.XPATH,"//span[@class='lister-item-year text-muted unbold']"):
    Year_span.append(i.text)
    
    
# scraped data of Genre
for i in driver.find_elements(By.XPATH,"//span[@class='genre']"):
    Genre.append(i.text)
    
    
# scraped data of Run time
for i in driver.find_elements(By.XPATH,"//span[@class='runtime']"):
    Run_time.append(i.text)
    
    
# scraped data of Ratings
for i in driver.find_elements(By.XPATH,"//div[@class='ipl-rating-star small']//span[2]"):
    Ratings.append(i.text)
    
    
# scraped data of Votes
for i in driver.find_elements(By.XPATH,"//div[@class='lister-item-content']//p[4]/span[2]"):
    Votes.append(i.text) 
    
    
# creating dataframe for scraped data
TV_Series = pd.DataFrame({})
TV_Series['Name'] = Name
TV_Series['Year Span'] = Year_span
TV_Series['Genre'] = Genre
TV_Series['Run Time'] = Run_time
TV_Series['Ratings'] = Ratings
TV_Series['Votes'] = Votes
TV_Series
# Out:
#                               Name    Year Span                     Genre  \
# 0                  Game of Thrones  (2011–2019)  Action, Adventure, Drama
# 1                  Stranger Things  (2016–2024)    Drama, Fantasy, Horror
# 2                 The Walking Dead  (2010–2022)   Drama, Horror, Thriller
# 3                   13 Reasons Why  (2017–2020)  Drama, Mystery, Thriller
# 4                          The 100  (2014–2020)    Drama, Mystery, Sci-Fi
# ..                             ...          ...                       ...
# 95                           Reign  (2013–2017)                     Drama
# 96  A Series of Unfortunate Events  (2017–2019)  Adventure, Comedy, Drama
# 97                  Criminal Minds     (2005– )     Crime, Drama, Mystery
# 98           Scream: The TV Series  (2015–2019)      Comedy, Crime, Drama
# 99      The Haunting of Hill House       (2018)    Drama, Horror, Mystery
#
#    Run Time Ratings      Votes
# 0    57 min     9.2  2,137,414
# 1    51 min     8.7  1,222,439
# 2    44 min     8.1  1,014,655
# 3    60 min     7.5    298,903
# 4    43 min     7.6    257,778
# ..      ...     ...        ...
# 95   42 min     7.4     50,998
# 96   50 min     7.8     63,010
# 97   42 min     8.1    204,832
# 98   45 min     7.1     42,408
# 99  572 min     8.6    253,435
#
# [100 rows x 6 columns]

# %%
driver.close()

# %% [markdown]
# ### Answer No.08

# %%
# getting the webpage of mentioned url
url = (" https://archive.ics.uci.edu/")
driver.get(url)

# %%
# fetching view all dataset button from the webpage
viewall_dataset = driver.find_element(By.XPATH,"//tbody[1]//tr/td[2]/span[2]/a")
page_url = viewall_dataset.get_attribute("href")
driver.get(page_url)
time.sleep(3)

# %%
# fetching page urls of all datasets
view_list = driver.find_element(By.XPATH,"/html/body/table[2]/tbody/tr/td[2]/table[1]/tbody/tr/td[2]/p/a")
list_url = view_list.get_attribute("href")
driver.get(list_url)
time.sleep(3)

# %%
# fetching urls for each dataset
dataset_url = driver.find_elements(By.XPATH,"//p[@class='normal']//b/a")

urls = []
for i in dataset_url:
    urls.append(i.get_attribute("href"))

# %%
# creating empty lists
Dataset_name = []
Data_type = []
Task = []
Attribute_type = []
No_of_instances = []
No_of_attributes = []
Year = []

for i in urls:
    driver.get(i)
    time.sleep(3)
    
    
    # scraping  Dataset name
    try:
        dataset_name = driver.find_element(By.XPATH,"//span[@class='heading']")
        Dataset_name.append(dataset_name.text)
    except NoSuchElementException:
        Dataset_name.append('-')
    time.sleep(3)
    
    
    
    # scraping data type
    try:
        data_type = driver.find_element(By.XPATH,"//table[@border='1']//tbody/tr/td[2]")
        if data_type.text == "N/A": raise NoSuchElementException
        Data_type.append(data_type.text)
    except NoSuchElementException:
        Data_type.append('-')
    time.sleep(3)
    
    
    # scraping Task
    try:
        task = driver.find_element(By.XPATH,"//table[@border='1']//tbody/tr[3]/td[2]")
        if task.text == "N/A": raise NoSuchElementException
        Task.append(task.text)
    except NoSuchElementException:
        Task.append('-')
    time.sleep(3)
    
    
    
    # scraping Attribute type
    try:
        attribute_type = driver.find_element(By.XPATH,"//table[@border='1']//tbody/tr[2]/td[2]")
        if attribute_type.text == "N/A": raise NoSuchElementException
        Attribute_type.append(attribute_type.text)
    except NoSuchElementException:
        Attribute_type.append('-')
    time.sleep(3)
    
    
    
    # scraping No of Instances
    try:
        instances = driver.find_element(By.XPATH,"//table[@border='1']//tbody/tr/td[4]")
        if instances.text == "N/A": raise NoSuchElementException
        No_of_instances.append(instances.text)
    except NoSuchElementException:
        No_of_instances.append('-')
    time.sleep(3)
    
    
    
    # scraping No of Arrtibutes
    try:
        attribute = driver.find_element(By.XPATH,"//table[@border='1']//tbody/tr[2]/td[4]")
        if attribute.text == "N/A": raise NoSuchElementException
        No_of_attributes.append(attribute.text)
    except NoSuchElementException:
        No_of_attributes.append('-')
    time.sleep(3)
    
    
    # scraping Year
    try:
        year = driver.find_element(By.XPATH,"//table[@border='1']//tbody/tr[2]/td[6]")
        if year.text == "N/A": raise NoSuchElementException
        Year.append(year.text[:4])
    except NoSuchElementException:
        Year.append('-')
    time.sleep(3)

# %%
# creating dataframe for scraped data
ML = pd.DataFrame({})
ML['Data Name'] = Data_name 
ML['Data Type '] = Data_type
ML['Task '] = Task 
ML['Attribute Type '] = Attribute_type 
ML['No of Instance '] = No_of_instances
ML['No of Attributes '] = No_of_attributes 
ML['Year '] = Year 
ML

# %%
driver.close()

# %% [markdown]
# ### Answer No.09

# %%
# getting the webpage of mentioned url
url = ("https://www.naukri.com/hr-recruiters-consultants")
driver.get(url)
time.sleep(3)

# %%
# fetching urls to navigate recruiter page
recruiter = driver.find_element(By.XPATH,"//a[@title='Search Recruiters']")
page_url = recruiter.get_attribute("href")

driver.get(page_url)
time.sleep(3)

# %%
# fetching search button, sending keys and clicking on it
search = driver.find_element(By.XPATH,"//div[@class='inpWrap']//input")
search.send_keys("Data Science")

btn = driver.find_element(By.XPATH,"//button[@class='fl qsbSrch blueBtn']").click()
time.sleep(3)

# %%
# creating empty lists
Name = []
Designation = []
Company = []
Skills = []
Location = []

# scraping data of Names
for i in driver.find_elements(By.XPATH,"//span[@class='fl ellipsis']"):
    Name.append(i.text)
time.sleep(3)


# scraping data of Designation
for i in driver.find_elements(By.XPATH,"//span[@class='ellipsis clr']"):
    Designation.append(i.text)
time.sleep(3)


# scraping data of Company Name
for i in driver.find_elements(By.XPATH,"//div[@class='vcard']//p[1]/a[2]"):
    Company.append(i.text)
time.sleep(3)


# scraping data of Skills
for i in driver.find_elements(By.XPATH,"//div[@class='hireSec highlightable']"):
    try:
        if i.text == "Not Specified": raise NoSuchElementException
        Skills.append(i.text)
    except NoSuchElementException:
        Skills.append('-')
time.sleep(3)


# scraping data of Location
for i in driver.find_elements(By.XPATH,"//div[@class='vcard']//p[1]/span/small"):
    try:
        if i.text == "Not Specified": raise NoSuchElementException
        Location.append(i.text)
    except NoSuchElementException:
        Location.append('-')
time.sleep(3)


# creating dataframe for scraped data
Naukri = pd.DataFrame({})
Naukri['Name'] = Name[:49]
Naukri['Designation'] = Designation[:49]
Naukri['Company'] = Company[:49]
Naukri['Skills'] = Skills[:49]
Naukri['Location'] = Location[:49]
Naukri
# Out:
#                                              Name  \
# 0                                    Aakash Harit
# 1                            shravan Kumar Gaddam
# 2                        MARSIAN Technologies LLP
# 3                                    Anik Agrawal
# 4                                    subhas patel
# 5    Abhishek - Only Analytics Hiring - India and
# 6   Institute for Financial Management and Resear
# 7                                     Balu Ramesh
# 8                                   Asif Lucknowi
# 9                                 InstaFinancials
# 10                                Kalpana Dumpala
# 11                                        Mubarak
# 12                                 Kushal Rastogi
# 13                             Mahesh Babu Channa
# 14                                 Priyanka Akiri
# 15                                   Kapil Devang
# 16                             Vaishnavi Kudalkar
# 17                                Sakshi Chhikara
# 18                                    Ruchi Dhote
# 19                                  Manisha Yadav
# 20                                    Riya Rajesh
# 21                           Rashmi Bhattacharjee
# 22                                  Faizan Kareem
# 23                                 Rithika dadwal
# 24                             Sandhya Khandagale
# 25                                      Shaun Rao
# 26                               Deeparchi Sharma
# 27                                  Azahar Shaikh
# 28                                          Manas
# 29                                          kumar
# 30                                   Sunil Vedula
# 31                                    Rajat Kumar
# 32                                Dhruv Dev Dubey
# 33                                  Avnish Mishra
# 34                                      Jayanth N
# 35                                         Avodha
# 36                                    Priya Khare
# 37                                    Amit Sharma
# 38                                          Kanan
# 39                           Shashikant Chaudhary
# 40                                           Brad
# 41                                   Rutuja Pawar
# 42                            Madhusudhan Sridhar
# 43                                    Ankit Sinha
# 44                                 Gaurav Chouhan
# 45                                   Rashi Kacker
# 46                                        Ashwini
# 47                                   Balaji Kolli
# 48                                 Rajani Nagaraj
#
#                                    Designation  \
# 0                                   HR Manager
# 1                            Company Recruiter
# 2                                   Company HR
# 3                            Company Recruiter
# 4                                  Founder CEO
# 5                  Recruitment Lead Consultant
# 6                            Programme Manager
# 7                             HR Administrator
# 8                                     Director
# 9                               Human Resource
# 10                            Executive Hiring
# 11                                  Company HR
# 12                                  Company HR
# 13                                HR Team Lead
# 14                                  HR Manager
# 15                                  HR Manager
# 16                                HR Executive
# 17                        Assistant Manager HR
# 18         Senior Executive Talent Acquisition
# 19                                HR Executive
# 20                  Manager Talent Acquisition
# 21                                     HR Head
# 22                                  HR MANAGER
# 23                                HR Recruiter
# 24                                HR Recruiter
# 25                     Manager Human Resources
# 26                           Company Recruiter
# 27                           Company Recruiter
# 28                     Lead Talent acquisition
# 29                                  Proprietor
# 30                                         CEO
# 31                                 Founder CEO
# 32                    Company Recruitment Head
# 33  Senior Technical &amp; Corporate Recruiter
# 34                             Project Manager
# 35              Business Development Associate
# 36                              Senior Manager
# 37                                  Consultant
# 38                senior technology instructor
# 39                    HR Recruiter/HR Excutive
# 40               Manager, Technical Recruiting
# 41                         Technical Recruiter
# 42                             Erp Implementer
# 43                              Head Analytics
# 44                     Chief Technical Officer
# 45                          Sr Product Manager
# 46                    Director Global Delivery
# 47                                  Co Founder
# 48                                  HR Manager
#
#                                            Company  \
# 0                             Data Science Network
# 1                    Shore Infotech India Pvt. Ltd
# 2                         MARSIAN Technologies LLP
# 3            Enerlytics Software Solutions Pvt Ltd
# 4                                  LibraryXProject
# 5       Apidel Technologies Division of Transpower
# 6                                             IFMR
# 7                      Techvantage Systems Pvt Ltd
# 8                       Weupskill- Live Wire India
# 9                 CBL Data Science Private Limited
# 10                              Innominds Software
# 11                                        MoneyTap
# 12              QuantMagnum Technologies Pvt. Ltd.
# 13                               SocialPrachar.com
# 14                   Infinitive Software Solutions
# 15                                  BISP Solutions
# 16                             Codeachive learning
# 17                   BIZ INFOTECNO PRIVATE LIMITED
# 18                           Bristlecone India Ltd
# 19                                        Easi Tax
# 20                     Novelworx Digital Solutions
# 21         AXESTRACK SOFTWARE SOLUTIONS PRIVATE...
# 22                   FirstTech Consaltants Pvt.Ltd
# 23                                Affine Analytics
# 24                 Compumatrice Multimedia Pvt Ltd
# 25                              Exela Technologies
# 26                                          ZIGRAM
# 27                 NEAL ANALYTICS SERVICES PVT LTD
# 28      Autumn Leaf Consulting Services Private...
# 29                                         trainin
# 30                            Nanoprecise Sci Corp
# 31                  R.S Consultancy &amp; Services
# 32                               NETAPS FOUNDATION
# 33                   RMS Risk Management Solutions
# 34        Dollarbird Information Services Pvt, Ltd
# 35                              Nikitha Palaparthi
# 36                          Independent Consultant
# 37                                 ASCO consulting
# 38                                         NY INST
# 39  3D India Staffing Research &amp; Consulting...
# 40                                     O.C. Tanner
# 41                                   Demand Matrix
# 42                             MADHUSUDHAN SRIDHAR
# 43                                  Suntech Global
# 44                        Strategic Consulting Lab
# 45                            Impel Labs Pvt. Ltd.
# 46                                    MRP Advisers
# 47                   Saras Solutions India Pvt Ltd
# 48                                     WildJasmine
#
#                                                Skills  \
# 0   Classic ASP Developer, Internet Marketing Prof...
# 1   .Net, Java, Data Science, Linux Administration...
# 2   Data Science, Artificial Intelligence, Machine...
# 3   Mean Stack, javascript, angularjs, mongodb, We...
# 4   Hadoop, Spark, Digital Strategy, Data Architec...
# 5   Analytics, Business Intelligence, Business Ana...
# 6                                        Data Science
# 7   Machine Learning, algorithms, Go Getter, Compu...
# 8   Technical Training, Software Development, Pres...
# 9   Software Development, It Sales, Account Manage...
# 10  Qa, Ui/ux, Java Developer, Java Architect, C++...
# 11  Business Intelligence, Data Warehousing, Data ...
# 12  Office Administration, Hr Administration, tele...
# 13  Social Media, digital media maketing, seo, smm...
# 14  Oracle Dba, Data Science, Data Warehousing, ET...
# 15     Big Data, Hadoop, Data Analytics, Data Science
# 16               Data Science, Python, Data Analytics
# 17  React.js, Data Science, Java, Front End, Busin...
# 18  Qlikview, Qlik Sense, Microsoft Azure, Power B...
# 19  Telecalling, Client Interaction, Marketing, Re...
# 20                                       Data Science
# 21  Corporate Sales, Software Development, Softwar...
# 22  Data Analytics, Data Science, Machine Learning...
# 23  Data Science, Machine Learning, Python, R, Dee...
# 24  Big Data, Data Science, Artificial Intelligenc...
# 25  Java, Net, Angularjs, Hr, Infrastructure, Mana...
# 26  Research, Digital Marketing, Analytics, Softwa...
# 27  Data Science, Artificial Intelligence, Machine...
# 28  Software Architecture, Vp Engineering, Product...
# 29  Data Science, Hadoop, Rpas, Devops, Python, Aw...
# 30  Signal Processing, Machine Learning, Neural Ne...
# 31  Web Technologies, Project Management, Software...
# 32  Server Administartion, Verilog, Vhdl, Digital ...
# 33  Data Science, Machine Learning, Deep Learning,...
# 34  Data Analytics, Managed Services, Team Leading...
# 35  Ethical Hacking, Security Operations Center, S...
# 36  Data Science, Artificial Intelligence, analyti...
# 37  Machine Learning, Artificial Intelligence, Dat...
# 38  C, C++, Artificial Intelligence, Python, Php, ...
# 39  Relationship Management, Retail Sales, Private...
# 40                 Data Science, Software Engineering
# 41  Data Science, Big Data Analytics, Digital Mark...
# 42                  Data Science, Recruitment, Salary
# 43  B.Tech, Tableau, Statistics, R, Analytics, Tim...
# 44  Software Development, Business Intelligence, B...
# 45                   Data Science, Node.js, Angularjs
# 46  Data Science, Media Marketing, Resource Planni...
# 47  Data Analysis, Learning, Data Science, Compute...
# 48  Java, Hadoop, R, Machine Learning, Spark, Flum...
#
#                     Location
# 0                      Delhi
# 1   Hyderabad / Secunderabad
# 2                       Pune
# 3                  Ahmedabad
# 4              UK - (london)
# 5          Vadodara / Baroda
# 6                    Chennai
# 7                 Trivandrum
# 8                     Indore
# 9      Bengaluru / Bangalore
# 10  Hyderabad / Secunderabad
# 11     Bengaluru / Bangalore
# 12                    Mumbai
# 13  Hyderabad / Secunderabad
# 14                 Hyderabad
# 15                    Bhopal
# 16                    Mumbai
# 17                Chandigarh
# 18                      Pune
# 19               Navi Mumbai
# 20                    Cochin
# 21                     Delhi
# 22  Hyderabad / Secunderabad
# 23                      Pune
# 24                      Pune
# 25                      Pune
# 26                   Gurgaon
# 27                      Pune
# 28     Bengaluru / Bangalore
# 29     Bengaluru / Bangalore
# 30                     Delhi
# 31     Bengaluru / Bangalore
# 32                     Noida
# 33           Mysoru / Mysore
# 34  Hyderabad / Secunderabad
# 35     Bengaluru / Bangalore
# 36                 New Delhi
# 37                   Chennai
# 38                   Aligarh
# 39            Salt Lake City
# 40                      Pune
# 41     Bengaluru / Bangalore
# 42                    Mumbai
# 43                    Indore
# 44     Bengaluru / Bangalore
# 45                    MYSORE
# 46  Hyderabad / Secunderabad
# 47     Bengaluru / Bangalore
# 48                    Mumbai

# %%
driver.close()
